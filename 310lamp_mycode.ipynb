# %% [markdown]
# <a href="https://colab.research.google.com/github/nicol2020/UV-SINTEC/blob/master/310lamp_mycode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 310 lamp
#
#
# Output is an interactiv 3D model in x,y,z coordinates with option:rotating, zooming.
# Positions of LEDs are plotted in x,y coordinates, find below 3D model.
#
#
# Power density for LEDs , 300mA:
#
# **Current 300mA.**
#
# 310nm LED - 1.84 W/m^2 at 4cm distance, 60deg angle
#
# 430nm LED - 4.98 W/m^2 at 10cm distance, 64deg angle
#
# 660nm LED - 3.74 W/m^2 at 10cm distance, 63deg angle
#
# 735nm LED - 0.507 W/m^2 at 15cm distance,65deg angle
#
# **Current 400mA**
#
# 430nm LED - 6.55 W/m^2 at 10cm distance, 64deg angle
#
# 660nm LED - 4.74 W/m^2 at 10cm distance, 63deg angle
#
# **Current 450mA**
#
# 430nm LED - 7.17 W/m^2 at 10cm distance, 64deg angle
#
# 660nm LED - 5.54 W/m^2 at 10cm distance, 63deg angle
#
# **Current 500mA**
#
# 310nm LED - 3 W/m^2 at 4cm distance, 60deg angle
#
# **Current 600mA**
#
# 735nm LED - 2.24 W/m^2 at 10cm distance,65deg angle

# %%
####################  ########################
import numpy as np
import matplotlib.pyplot as plt

I_zero = 5.54#Power Density in w/m^2 at a given height h from the LED
h = 0.10 #height from the LED to the plane given for Power density
Ir0 = I_zero*(h**2) #Intensity value in cd

z_distance = 0.20
#psi angle ( psi is angle at half of max intensity)
psi_angle = 63

#LEDs array coordinates
#saving LEDs positions to xlist and ylist for calculation
# 
#xlist = [0, -0.005915, 0.004915, -0.005915, 0.004915 ]
#ylist = [0, 0.00611, 0.00611, -0.00642, -0.00642]
#1(-5.915,6.11 );2(4.915, 6.11);UV(0,0);3(-5.915, -6.42);4(4.915, -6.42) 

xlist = [-0.005915, -0.005915]
ylist = [0.00611, -0.00642]

LED_n = 8 # number of tiles

# LEDs coordinates centered at (0,0)
#empty lists for saving LEDs coordinates
xlist_11 = [] # x coordinates for 1 unit
xlist_22 = [] # x coordinates for 2 unit
xlist_33 = [] # x coordinates for 3 unit
xlist_44 = [] # x coordinates for 4 unit
xlist_55 = [] # x coordinates for 5 unit
xlist_66 = [] # x coordinates for 6 unit
xlist_77 = [] # x coordinates for 7 unit
xlist_88 = [] # x coordinates for 8 unit
xlist_89 = []
ylist_11 = [] # y coordinates for 1 unit
ylist_22 = [] # y coordinates for 2 unit
ylist_33 = [] # y coordinates for 3 unit
ylist_44 = [] # y coordinates for 4 unit
ylist_55 = [] # y coordinates for 5 unit
ylist_66 = [] # y coordinates for 6 unit
ylist_77 = [] # y coordinates for 7 unit
ylist_88 = [] # y coordinates for 8 unit
ylist_89 = []

#below 
a= 0.17
b= 0.17
c = 0.17
for i in range(len(xlist)):
  xlist_11.append(xlist[i]+c)
  ylist_11.append(ylist[i]+a)

  xlist_22.append(xlist[i])
  ylist_22.append(ylist[i]+a)

  xlist_33.append(xlist[i]-c)
  ylist_33.append(ylist[i]+a)

  xlist_44.append(xlist[i]+b)
  ylist_44.append(ylist[i])

  xlist_55.append(xlist[i]-b)
  ylist_55.append(ylist[i])

  xlist_66.append(xlist[i]+c)
  ylist_66.append(ylist[i]-a)

  xlist_77.append(xlist[i])
  ylist_77.append(ylist[i]-a)

  xlist_88.append(xlist[i]-c)
  ylist_88.append(ylist[i]-a)

 
# save LEDs list to one list  which would be used for futher calculation
xlist.extend(xlist_11)
ylist.extend(ylist_11)

xlist.extend(xlist_22)
ylist.extend(ylist_22)

xlist.extend(xlist_44)
ylist.extend(ylist_44)

xlist.extend(xlist_33)
ylist.extend(ylist_33)

xlist.extend(xlist_55)
ylist.extend(ylist_55)

xlist.extend(xlist_66)
ylist.extend(ylist_66)

xlist.extend(xlist_77)
ylist.extend(ylist_77)

xlist.extend(xlist_88)
ylist.extend(ylist_88)


#xlistt = [0, 0.10, -0.10, ]
#ylistt = [0]
#xlist.extend(xlistt)
#ylist.extend(ylistt)


# deleting the (0,0) LED from list, commet this two lines if you work with LED positioned at (0, 0)
del xlist[0:2]
del ylist[0:2]


#printing the LEDs positions, just for checking is every positions calulated correctly
print(f"LEDs X coordinates (x1, x2, x3...) = {xlist}")
print(f"LEDs Y coordinates (y1, y2, y3...) = {ylist}")

# Gettting a points in a target plane (xp,yp) in mm
a = 100
y_numpy = np.linspace(-0.15,0.15,a)
x_numpy = np.linspace(-0.15,0.15,a)
xplist = []
yplist = []

for x in x_numpy:
  for y in y_numpy:
    xplist.append(x)
    yplist.append(y)

#####Calculating irradiance#######
intensity_point = []
m = -( np.log(2) / np.log(np.cos(np.radians(psi_angle)))) 



inten_sum_point = [] #empty list for saving results
for xp,yp in zip(xplist,yplist):
  intensity_point = []
  for x,y in zip(xlist,ylist):    
    E_point = ((z_distance**(m+1))*Ir0) / (((xp-x)**2) + ((yp-y)**2) + (z_distance**2))**((m+3)/2)
    intensity_point.append(E_point) 
  inten_sum_point.append(sum(intensity_point))

#for ploting 
start1 = np.max(inten_sum_point)
end1= start1 * 0.9
print(f"Max intensity in target plane: {np.max(inten_sum_point)}")
print(f"Min intenisty in target plane: {np.min(inten_sum_point)}")  
print(f"Uniformity:{np.min(inten_sum_point)/np.max(inten_sum_point)}")

print(f"90 % of max intenisty : {end1}")


import plotly.graph_objects as go
import plotly.offline as go_offline
#prepare data in 
nten_numpy = np.array(inten_sum_point)
Z =  nten_numpy.reshape(a,a)
fig=go.Figure(data = go.Surface(z=Z, x = x_numpy, y = y_numpy,opacity=0.9, colorscale='Viridis'))
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                             highlightcolor="limegreen", project_z=True))
fig.update_layout(title=(f" distance: {z_distance}(mm) and half angle:{psi_angle}deg"))  
fig.show()

fig = go.Figure(data =
    go.Contour(z=Z,x=x_numpy, # horizontal axis
               y=y_numpy, # vertical axis
            contours=dict(
            coloring ='heatmap',
            showlabels = True, # show labels on contours
            labelfont = dict( # label font properties
                size = 12,
                color = 'white',
            )
    )))
fig.show()

fig = go.Figure( data = go.Scatter(x = xlist, y =ylist, opacity=0.9, mode='markers'))
fig.update_layout(title=("LEDs positions")) 
fig.show()
# Out:
# LEDs X coordinates (x1, x2, x3...) = [0.164085, 0.164085, -0.005915, -0.005915, 0.164085, 0.164085, -0.17591500000000002, -0.17591500000000002, -0.17591500000000002, -0.17591500000000002, 0.164085, 0.164085, -0.005915, -0.005915, -0.17591500000000002, -0.17591500000000002]
# LEDs Y coordinates (y1, y2, y3...) = [0.17611000000000002, 0.16358, 0.17611000000000002, 0.16358, 0.00611, -0.00642, 0.17611000000000002, 0.16358, 0.00611, -0.00642, -0.16389, -0.17642000000000002, -0.16389, -0.17642000000000002, -0.16389, -0.17642000000000002]
# Max intensity in target plane: 6.339458162989283
# Min intenisty in target plane: 5.817943691123221
# Uniformity:0.9177351662464244
# 90 % of max intenisty : 5.705512346690355
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f1bec50e-1228-4acc-bc73-0b78f1ccc6f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1bec50e-1228-4acc-bc73-0b78f1ccc6f0")) {
#                     Plotly.newPlot(
#                         'f1bec50e-1228-4acc-bc73-0b78f1ccc6f0',
#                         [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "contours": {"z": {"highlightcolor": "limegreen", "project": {"z": true}, "show": true, "usecolormap": true}}, "opacity": 0.9, "type": "surface", "x": [-0.15, -0.14696969696969697, -0.14393939393939392, -0.1409090909090909, -0.13787878787878788, -0.13484848484848483, -0.1318181818181818, -0.12878787878787878, -0.12575757575757576, -0.12272727272727273, -0.11969696969696969, -0.11666666666666667, -0.11363636363636363, -0.1106060606060606, -0.10757575757575757, -0.10454545454545454, -0.1015151515151515, -0.09848484848484848, -0.09545454545454546, -0.09242424242424241, -0.08939393939393939, -0.08636363636363636, -0.08333333333333333, -0.08030303030303029, -0.07727272727272727, -0.07424242424242423, -0.07121212121212121, -0.06818181818181818, -0.06515151515151514, -0.06212121212121212, -0.05909090909090908, -0.05606060606060606, -0.053030303030303025, -0.04999999999999999, -0.04696969696969697, -0.04393939393939393, -0.04090909090909091, -0.03787878787878787, -0.03484848484848484, -0.031818181818181815, -0.02878787878787878, -0.025757575757575757, -0.022727272727272735, -0.019696969696969685, -0.016666666666666663, -0.013636363636363641, -0.010606060606060591, -0.007575757575757569, -0.004545454545454547, -0.0015151515151514972, 0.001515151515151525, 0.004545454545454547, 0.007575757575757569, 0.010606060606060619, 0.013636363636363641, 0.016666666666666663, 0.019696969696969713, 0.022727272727272735, 0.025757575757575757, 0.028787878787878807, 0.03181818181818183, 0.03484848484848485, 0.03787878787878787, 0.04090909090909092, 0.043939393939393945, 0.04696969696969697, 0.05000000000000002, 0.05303030303030304, 0.05606060606060606, 0.05909090909090908, 0.06212121212121213, 0.06515151
class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2bef1114-5309-4671-8e78-1667c1fa9d34")) {
#                     Plotly.newPlot(
#                         '2bef1114-5309-4671-8e78-1667c1fa9d34',
#                         [{"mode": "markers", "opacity": 0.9, "type": "scatter", "x": [0.164085, 0.164085, -0.005915, -0.005915, 0.164085, 0.164085, -0.17591500000000002, -0.17591500000000002, -0.17591500000000002, -0.17591500000000002, 0.164085, 0.164085, -0.005915, -0.005915, -0.17591500000000002, -0.17591500000000002], "y": [0.17611000000000002, 0.16358, 0.17611000000000002, 0.16358, 0.00611, -0.00642, 0.17611000000000002, 0.16358, 0.00611, -0.00642, -0.16389, -0.17642000000000002, -0.16389, -0.17642000000000002, -0.16389, -0.17642000000000002]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The below is code for 3D model where 6 units are placed in regular hexagon.
# A regular hexagon is with six equal sides, side is named as "a" in the code.
# Idea is to change a lenght of side "a" in term of better uniformity.
# Output is an 3D model of irradiance and calculations such as Emin, E avarage, factor uniformity "u".

# %%
#################### The six 17LEDs units placed in regular hexagon shape ########################
import numpy as np
import matplotlib.pyplot as plt
import statistics
# distance and angle

psi_angle = 63 #psi angle ( psi is angle at half of max intensity)
psi = psi_angle * np.pi/180 # convert into radians


# LEDs coordinates centered at (0,0)
#empty lists for saving LEDs coordinates
xlist_11 = [] # x coordinates for 1 unit
xlist_22 = [] # x coordinates for 2 unit
xlist_33 = [] # x coordinates for 3 unit
xlist_44 = [] # x coordinates for 4 unit
xlist_55 = [] # x coordinates for 5 unit
xlist_66 = [] # x coordinates for 6 unit

ylist_11 = [] # y coordinates for 1 unit
ylist_22 = [] # y coordinates for 2 unit
ylist_33 = [] # y coordinates for 3 unit
ylist_44 = [] # y coordinates for 4 unit
ylist_55 = [] # y coordinates for 5 unit
ylist_66 = [] # y coordinates for 6 unit

# LEDs coordinates centered at (0,0)
xlist_0 = [0]
ylist_0 = [0]


####getting coordinates for a 6 units
a = 0.17 # distance from (0,0)(mm)
r = (np.sqrt(3)*a)/2
i = 0
xlist_11.append(xlist_0[i]+a)
xlist_22.append(xlist_0[i]+(a/2))
xlist_33.append(xlist_0[i]-(a/2))
xlist_44.append(xlist_0[i]-a)
xlist_55.append(xlist_0[i]-(a/2))
xlist_66.append(xlist_0[i]+(a/2))

ylist_11.append(ylist_0[i])
ylist_22.append(ylist_0[i]-r)
ylist_33.append(ylist_0[i]-r)
ylist_44.append(ylist_0[i])
ylist_55.append(ylist_0[i]+r)
ylist_66.append(ylist_0[i]+r)
  
xlist_11.extend(xlist_22)
xlist_11.extend(xlist_33)
xlist_11.extend(xlist_44)
xlist_11.extend(xlist_55)
xlist_11.extend(xlist_66)

ylist_11.extend(ylist_22)
ylist_11.extend(ylist_33)
ylist_11.extend(ylist_44)
ylist_11.extend(ylist_55)
ylist_11.extend(ylist_66)

listx = [0]
listy = [0]

xlist_11.extend(listx)
ylist_11.extend(listy)


# Gettting a points in a target plane (xp,yp) in mm
point= 60 # number of points b*b
x_numpy = np.linspace(-0.15,0.15,point)
y_numpy = np.linspace(-0.15,0.15,point)
xplist = []
yplist = []

for x in x_numpy:
  for y in y_numpy:
    xplist.append(x)
    yplist.append(y)

#####Calculating irradiance#######
intensity_point = []
m = -( np.log(2) / np.log(np.cos(psi))) 



inten_sum_point = [] #empty list for saving results
for xp,yp in zip(xplist,yplist):
  intensity_point = []
  for x,y in zip(xlist_11,ylist_11):    
    E_point = ((z_distance**(m+1))*Ir0) / (((xp-x)**2) + ((yp-y)**2) + (z_distance**2))**((m+3)/2)
    intensity_point.append(E_point) 
  inten_sum_point.append(sum(intensity_point))


#statistics
import statistics
print(f"Max intensity in target plane: {np.max(inten_sum_point)}")
print(f"Min intenisty in target plane: {np.min(inten_sum_point)}")  
print(f"Uniformity:{np.min(inten_sum_point)/np.max(inten_sum_point)}")


import plotly.graph_objects as go
import plotly.offline as go_offline
#prepare data in 
nten_numpy = np.array(inten_sum_point)
Z =  nten_numpy.reshape(point,point) #reshaping list to array shape(b , b)
fig=go.Figure(data = go.Surface(z=Z, x = x_numpy, y = y_numpy,opacity=0.9, colorscale='Viridis'))
                      
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                             highlightcolor="limegreen", project_z=True))
fig.update_layout(title=(f" 17LEDs units , distance: {z_distance}(mm) and half angle:{psi_angle}deg"))  
fig.show()

fig = go.Figure( data = go.Scatter(x = xlist_11, y =ylist_11, opacity=0.9, mode='markers'))
fig.update_layout(title=("LEDs positions")) 
fig.show()
# Out:
# Max intensity in target plane: 4.279832589423326
# Min intenisty in target plane: 2.590959161027514
# Uniformity:0.6053879694805131
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="da5d1118-782c-4ac3-b020-1ecf4cbe14a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da5d1118-782c-4ac3-b020-1ecf4cbe14a7")) {
#                     Plotly.newPlot(
#                         'da5d1118-782c-4ac3-b020-1ecf4cbe14a7',
#                         [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "contours": {"z": {"highlightcolor": "limegreen", "project": {"z": true}, "show": true, "usecolormap": true}}, "opacity": 0.9, "type": "surface", "x": [-0.15, -0.14491525423728813, -0.13983050847457626, -0.1347457627118644, -0.12966101694915255, -0.12457627118644067, -0.11949152542372882, -0.11440677966101695, -0.10932203389830508, -0.10423728813559321, -0.09915254237288135, -0.0940677966101695, -0.08898305084745763, -0.08389830508474576, -0.0788135593220339, -0.07372881355932204, -0.06864406779661017, -0.0635593220338983, -0.058474576271186435, -0.05338983050847458, -0.048305084745762714, -0.043220338983050846, -0.03813559322033899, -0.033050847457627125, -0.027966101694915257, -0.02288135593220339, -0.017796610169491522, -0.012711864406779655, -0.007627118644067815, -0.0025423728813559476, 0.00254237288135592, 0.007627118644067787, 0.012711864406779655, 0.017796610169491522, 0.02288135593220339, 0.027966101694915257, 0.033050847457627125, 0.038135593220338965, 0.04322033898305083, 0.0483050847457627, 0.05338983050847457, 0.058474576271186435, 0.0635593220338983, 0.06864406779