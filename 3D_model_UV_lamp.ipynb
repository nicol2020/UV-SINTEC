# %% [markdown]
# <a href="https://colab.research.google.com/github/nicol2020/UV-SINTEC/blob/master/3D_model_UV_lamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **3D model of UV lamp **
#
# The (x, y)coordinates of each diode are taken from pcb board and saved to  xlist and ylist lists. The LEDs are saved in order:
#
# 310_2 = (xlist[0], ylist[0])
#
# 340 = (xlist[1], ylist[1])
#
# 310_3 = (xlist[2], ylist[2])
#
# 370 = (xlist[3], ylist[3])
#
# 325 = (xlist[4], ylist[4])
#
# 405 = (xlist[5], ylist[5])
#
# 310_5 = (xlist[6], ylist[6])
#
# 395 = (xlist[7], ylist[7])
#
# 385 = (xlist[8], ylist[8])
#
# 365 = (xlist[9], ylist[9])
#
# 310_4 = (xlist[10], ylist[10])
#
# 280 =  (xlist[11], ylist[11])
#
# 310_1 = (xlist[12], ylist[12])
#
# UV lamp is centered at (0,0) with 310_5 in the center.
# Under section 'Calculating irradianice' it is posible to change a distance z_distance, half angle psi, Iro intensity of LEDs.
# Irradiance is calculated in 200*200 plane, but is option to change a size of target plane --> to do that change number in  x_numpy variable and  y_numpy variable.
# Output is an interactiv 3D model in x,y,z coordinates with option:rotating, zooming.
# Positions of LEDs are plotted in x,y coordinates, find below 3D model.

# %%
####################  UV lamp   ########################
import numpy as np
import matplotlib.pyplot as plt


#LEDs array coordinates
xlist = [9.5, 18.05, 26.41, 13.83, 21.60, 9.9, 18, 25.09, 13.39, 21.9, 9.59, 17.88, 26.18]
ylist = [9.5, 8.15, 9.5, 13.94, 14.44, 17.82, 18, 17.37, 22.26, 21.84, 25.84, 26.19, 25.90]

# LEDs coordinates centered at (0,0)
xlist0 = []
ylist0 = []
b = 18 
for i in range(len(xlist)):
  xlist0.append(xlist[i]-b)
  ylist0.append(ylist[i]-b)

# Gettting a points in a target plane (xp,yp) in mm
a = 30
x_numpy = np.linspace(-100,100,a) #dimension of target plane
y_numpy = np.linspace(-100,100,a) #dimension of target plane
xplist = []
yplist = []

for x in x_numpy:
  for y in y_numpy:
    xplist.append(x)
    yplist.append(y)

#####Calculating irradiance#######
intensity_point = []
z_distance = 150
#psi angle ( psi is angle at half of max intensity)
psi_angle = 90
psi = psi_angle * np.pi/180 # convert into radians
m = -( np.log(2) / np.log(np.cos(psi))) 
Ir0 = 20 #(mW)   # intensity


inten_sum_point = [] #empty list for saving results
for xp,yp in zip(xplist,yplist):
  intensity_point = []
  for x,y in zip(xlist0,ylist0):    
    E_point = ((z_distance**(m+1))*Ir0) / (((xp-x)**2) + ((yp-y)**2) + (z_distance**2))**((m+3)/2)
    intensity_point.append(E_point) 
  inten_sum_point.append(sum(intensity_point))

import plotly.graph_objects as go
import plotly.offline as go_offline
#prepare data in 
nten_numpy = np.array(inten_sum_point)
Z =  nten_numpy.reshape(a,a)
fig=go.Figure(data = go.Surface(z=Z, x = x_numpy, y = y_numpy,opacity=0.9, colorscale='Viridis'))
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                             highlightcolor="limegreen", project_z=True))
fig.update_layout(title=(f" UV LEDs unit, distance: {z_distance}(mm) and half angle:{psi_angle}deg"))  
fig.show()

fig = go.Figure( data = go.Scatter(x = xlist0, y =ylist0, opacity=0.9, mode='markers'))
fig.update_layout(title = "UV lamp - LEDs positions ")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="
469734496, 0.004879023602636688, 0.004642814096951822], [0.004878407605863051, 0.005133819461959898, 0.005391442859477924, 0.005648806995028577, 0.005903070593636186, 0.006151049470906945, 0.006389267079284931, 0.0066140299721951755, 0.0068215282962414345, 0.0070079590692262005, 0.0071696673170319435, 0.0073032974447870625, 0.0074059449187920895, 0.0074752968739853955, 0.007509750011983518, 0.007508495331071239, 0.007471561810712542, 0.0073998148763071165, 0.007294909787674648, 0.007159204391921235, 0.006995639326891593, 0.006807596259337188, 0.006598745824932962, 0.006372896600143624, 0.0061338549057160935, 0.005885302900482297, 0.005630699712307834, 0.00537320767840321, 0.005115643442450658, 0.004860451869562333], [0.00509608570569125, 0.005371025385222648, 0.005649037333335209, 0.005927453345753282, 0.006203177453752276, 0.006472712459808343, 0.006732213053931559, 0.00697756821095657, 0.007204513464084108, 0.007408770854059681, 0.007586211089398378, 0.007733029106026911, 0.007845921297776871, 0.007922250763351207, 0.007960186472327707, 0.007958803586221495, 0.0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="48753581-6d37-4b80-861b-87e3183fda76" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("48753581-6d37-4b80-861b-87e3183fda76")) {
#                     Plotly.newPlot(
#                         '48753581-6d37-4b80-861b-87e3183fda76',
#                         [{"mode": "markers", "opacity": 0.9, "type": "scatter", "x": [-8.5, 0.05000000000000071, 8.41, -4.17, 3.6000000000000014, -8.1, 0, 7.09, -4.609999999999999, 3.8999999999999986, -8.41, -0.120000000000001, 8.18], "y": [-8.5, -9.85, -8.5, -4.0600000000000005, -3.5600000000000005, -0.17999999999999972, 0, -0.629999999999999, 4.260000000000002, 3.84, 7.84, 8.190000000000001, 7.899999999999999]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# Below is code for calculating the best position for four Uv units.
#
# At beginning, the UV lamps are arranged around (0,0). Code calculates a irradiance over the target plane, if u= minimum irradiance/ avarage irradiance is less than 0.8, each UV lamp will be moved 1mm in x direction and 1mm in y direction. Finally, when u >= 0.8, calculating will be stopped and 3D model will be given as an output. Positions of UV units are given in x,y plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

#LEDs array coordinates
xlist_1 = [9.5, 18.05, 26.41, 13.83, 21.60, 9.9, 18, 25.09, 13.39, 21.9, 9.59, 17.88, 26.18]
ylist_1 = [9.5, 8.15, 9.5, 13.94, 14.44, 17.82, 18, 17.37, 22.26, 21.84, 25.84, 26.19, 25.90]


# distance and angle
b = 30 # number of points b*b
x_numpy = np.linspace(-100,100,b)
y_numpy = np.linspace(-100,100,b)
xplist = []
yplist = []

for x in x_numpy:
  for y in y_numpy:
    xplist.append(x)
    yplist.append(y)

#####Calculating irradiance#######
#intensity_point = []
z_distance = 150
psi_angle = 90 #psi angle ( psi is angle at half of max intensity)
psi = psi_angle * np.pi/180 # convert into radians
m = -( np.log(2) / np.log(np.cos(psi))) 
Ir0 = 1 #(mW)   # intensity

u=0
a = 0 # distance between units(mm) x axis
c = 0 # distance between units(mm) y axis
while u<0.8:
  #getting coordinates : 4 units
  
  xlist_11 = [] # x coordinates for 1 unit
  xlist_22 = [] # x coordinates for 2 unit
  xlist_33 = [] # x coordinates for 3 unit
  xlist_44 = [] # x coordinates for 4 unit

  ylist_11 = [] # y coordinates for 1 unit
  ylist_22 = [] # y coordinates for 2 unit
  ylist_33 = [] # y coordinates for 3 unit
  ylist_44 = [] # y coordinates for 4 unit

  for i in range(len(xlist_1)):
    xlist_11.append(xlist_1[i]+a)
    xlist_22.append(xlist_1[i]+a)
    xlist_33.append((xlist_1[i]-36)-a)
    xlist_44.append((xlist_1[i]-36)-a)

    ylist_11.append(ylist_1[i]+a)
    ylist_22.append((ylist_1[i]-36)-a)
    ylist_33.append((ylist_1[i]-36)-a)
    ylist_44.append(ylist_1[i]+a)
  
  xlist_11.extend(xlist_22)
  xlist_11.extend(xlist_33)
  xlist_11.extend(xlist_44)
  ylist_11.extend(ylist_22)
  ylist_11.extend(ylist_33)
  ylist_11.extend(ylist_44)

  inten_sum_point = [] #empty list for saving results
  for xp,yp in zip(xplist,yplist):
    intensity_point = []
    for x,y in zip(xlist_11,ylist_11):    
      E_point = ((z_distance**(m+1))*Ir0) / (((xp-x)**2) + ((yp-y)**2) + (z_distance**2))**((m+3)/2)
      intensity_point.append(E_point) 
    inten_sum_point.append(sum(intensity_point))
  minim = min(inten_sum_point)

  E_avarage = (sum(inten_sum_point)) / (len(inten_sum_point))

  u = minim / E_avarage            
  print("5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8):", u)

  a+=1
  print(f"Distance between UV units :{a*2} (mm)")

#plotting results  
import plotly.graph_objects as go
import plotly.offline as go_offline
nten_numpy = np.array(inten_sum_point)
Z =  nten_numpy.reshape(b,b) #reshaping list to array shape(b , b)
fig=go.Figure(data = go.Surface(z=Z, x = x_numpy, y = y_numpy,opacity=0.9, colorscale='Viridis'))                     
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                             highlightcolor="limegreen", project_z=True))
fig.update_layout(title=(f" UV unit , distance: {z_distance}(mm) and half angle:{psi_angle}deg"))  
fig.show()


fig = go.Figure( data = go.Scatter(x = xlist_11, y =ylist_11, opacity=0.9, mode='markers'))
fig.update_layout(title = "LEDs positions for UV lamp")
fig.show()
# Out:
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5686551949957115
# Distance between UV units :2 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.570154370496886
# Distance between UV units :4 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5717385002201422
# Distance between UV units :6 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5734081563537151
# Distance between UV units :8 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.575163928447371
# Distance between UV units :10 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5770064215889058
# Distance between UV units :12 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5789362544868003
# Distance between UV units :14 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5809540574588449
# Distance between UV units :16 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5830604703266996
# Distance between UV units :18 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5852561402164472
# Distance between UV units :20 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.587541719265417
# Distance between UV units :22 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5899178622356703
# Distance between UV units :24 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5923852240348111
# Distance between UV units :26 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.594944457144944
# Distance between UV units :28 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.5975962089609265
# Distance between UV units :30 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6003411190392615
# Distance between UV units :32 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6031798162593307
# Distance between UV units :34 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6061129158989857
# Distance between UV units :36 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6091410166268411
# Distance between UV units :38 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.612264697414023
# Distance between UV units :40 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6154845143685174
# Distance between UV units :42 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6188009974957039
# Distance between UV units :44 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6222146473890761
# Distance between UV units :46 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6257259318557139
# Distance between UV units :48 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6293352824814947
# Distance between UV units :50 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6330430911415966
# Distance between UV units :52 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6368497064623949
# Distance between UV units :54 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6407554302414237
# Distance between UV units :56 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.644760513832639
# Distance between UV units :58 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6488651545048341
# Distance between UV units :60 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6530694917816657
# Distance between UV units :62 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.657373603772363
# Distance between UV units :64 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6617775035027996
# Distance between UV units :66 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6662811352572641
# Distance between UV units :68 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6708843709418248
# Distance between UV units :70 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6755870064808358
# Distance between UV units :72 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6803887582587157
# Distance between UV units :74 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6852892596196486
# Distance between UV units :76 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6902880574384667
# Distance between UV units :78 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.6953846087764393
# Distance between UV units :80 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.700578277636173
# Distance between UV units :82 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7058683318302489
# Distance between UV units :84 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7112539399785809
# Distance between UV units :86 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7167341686498255
# Distance between UV units :88 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7223079796623713
# Distance between UV units :90 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7279742275606269
# Distance between UV units :92 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7337316572824207
# Distance between UV units :94 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7395789020333232
# Distance between UV units :96 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7455144813836139
# Distance between UV units :98 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7515367996034265
# Distance between UV units :100 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7576441442513294
# Distance between UV units :102 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7638346850311656
# Distance between UV units :104 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7701064729315446
# Distance between UV units :106 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7764574396616442
# Distance between UV units :108 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7828853973963623
# Distance between UV units :110 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7893880388428851
# Distance between UV units :112 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.7959629376398861
# Distance between UV units :114 (mm)
# 5.Uniformity of E , u = Emin/Evarage, (the best is  u>0.8): 0.802607549099363
# Distance between UV units :116 (mm)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7a70e80c-cee4-4c02-bde4-40c9f9cc4529" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7a70e80c-cee4-4c02-bde4-40c9f9cc4529")) {
#                     Plotly.newPlot(
#                         '7a70e80c-cee4-4c02-bde4-40c9f9cc4529',
#                         [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "contours": {"z": {"highlightcolor": "limegreen", "project": {"z": true}, "show": true, "usecolormap": true}}, "opacity": 0.9, "type": "surface", "x": [-100.0, -93.10344827586206, -86.20689655172414, -79.3103448275862, -72.41379310344828, -65.51724137931035, -58.62068965517241, -51.724137931034484, -44.827586206896555, -37.931034482758626, -31.034482758620697, -24.13793103448276, -17.241379310344826, -10.344827586206904, -3.448275862068968, 3.4482758620689538, 10.34482758620689, 17.241379310344826, 24.137931034482747, 31.03448275862067, 37.931034482758605, 44.82758620689654, 51.72413793103448, 58.62068965517241, 65.51724137931035, 72.41379310344826, 79.31034482758619, 86.20689655172413, 93.10344827586206, 100.0], "y": [-100.0, -93.10344827586206, -86.20689655172414, -79.3103448275862, -72.41379310344828, -65.51724137931035, -58.62068965517241, -51.724137931034484, -44.827586206896555, -37.931034482758626, -31.034482758620697, -24.13793103448276, -17.241379310344826, -10.344827586206904, -3.448275862068968, 3.4482758620689538, 10.34482758620689, 17.241379310344826, 24.137931034482747, 31.03448275862067, 37.931034482758605,
#                         [{"mode": "markers", "opacity": 0.9, "type": "scatter", "x": [66.5, 75.05, 83.41, 70.83, 78.6, 66.9, 75, 82.09, 70.39, 78.9, 66.59, 74.88, 83.18, 66.5, 75.05, 83.41, 70.83, 78.6, 66.9, 75, 82.09, 70.39, 78.9, 66.59, 74.88, 83.18, -83.5, -74.95, -66.59, -79.17, -71.4, -83.1, -75, -67.91, -79.61, -71.1, -83.41, -75.12, -66.82, -83.5, -74.95, -66.59, -79.17, -71.4, -83.1, -75, -67.91, -79.61, -71.1, -83.41, -75.12, -66.82], "y": [66.5, 65.15, 66.5, 70.94, 71.44, 74.82, 75, 74.37, 79.26, 78.84, 82.84, 83.19, 82.9, -83.5, -84.85, -83.5, -79.06, -78.56, -75.18, -75, -75.63, -70.74, -71.16, -67.16, -66.81, -67.1, -83.5, -84.85, -83.5, -79.06, -78.56, -75.18, -75, -75.63, -70.74, -71.16, -67.16, -66.81, -67.1, 66.5, 65.15, 66.5, 70.94, 71.44, 74.82, 75, 74.37, 79.26, 78.84, 82.84, 83.19, 82.9]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# The below is code for 3D model where 6 units are placed in regular hexagon.
# A regular hexagon is with six equal sides, side is named as "a" in the code.
# Idea is to change a lenght of side "a" in term of better uniformity.
# Output is an 3D model of irradiance and calculations such as Emin, E avarage, factor uniformity "u".

# %%
#################### The six UV units placed in regular hexagon shape ########################
import numpy as np
import matplotlib.pyplot as plt
import statistics
# distance and angle
z_distance = 150
psi_angle = 60 #psi angle ( psi is angle at half of max intensity)
psi = psi_angle * np.pi/180 # convert into radians

#LEDs array coordinates
#LEDs array coordinates
xlist_1 = [9.5, 18.05, 26.41, 13.83, 21.60, 9.9, 18, 25.09, 13.39, 21.9, 9.59, 17.88, 26.18]
ylist_1 = [9.5, 8.15, 9.5, 13.94, 14.44, 17.82, 18, 17.37, 22.26, 21.84, 25.84, 26.19, 25.90]

#xlist_1 = [15.89, 15.89, 57.89, 57.89]
#ylist_1 = [8.405, 44.405, 8.405, 44.405]

# LEDs coordinates centered at (0,0)
#empty lists for saving LEDs coordinates
xlist_11 = [] # x coordinates for 1 unit
xlist_22 = [] # x coordinates for 2 unit
xlist_33 = [] # x coordinates for 3 unit
xlist_44 = [] # x coordinates for 4 unit
xlist_55 = [] # x coordinates for 5 unit
xlist_66 = [] # x coordinates for 6 unit

ylist_11 = [] # y coordinates for 1 unit
ylist_22 = [] # y coordinates for 2 unit
ylist_33 = [] # y coordinates for 3 unit
ylist_44 = [] # y coordinates for 4 unit
ylist_55 = [] # y coordinates for 5 unit
ylist_66 = [] # y coordinates for 6 unit

# LEDs coordinates centered at (0,0)
xlist_0 = []
ylist_0 = []
x1 = 18 # moving LEDs unit - x axis
y1 = 18 # moving LEDs unit - y axis
for i in range(len(xlist_1)):
  xlist_0.append(xlist_1[i]-x1)
  ylist_0.append(ylist_1[i]-y1)

####getting coordinates for a 6 units
a = 75 # distance from (0,0)(mm)
r = (np.sqrt(3)*a)/2
for i in range(len(xlist_0)):
  xlist_11.append(xlist_0[i]+a)
  xlist_22.append(xlist_0[i]+(a/2))
  xlist_33.append(xlist_0[i]-(a/2))
  xlist_44.append(xlist_0[i]-a)
  xlist_55.append(xlist_0[i]-(a/2))
  xlist_66.append(xlist_0[i]+(a/2))

  ylist_11.append(ylist_0[i])
  ylist_22.append(ylist_0[i]-r)
  ylist_33.append(ylist_0[i]-r)
  ylist_44.append(ylist_0[i])
  ylist_55.append(ylist_0[i]+r)
  ylist_66.append(ylist_0[i]+r)
  
xlist_11.extend(xlist_22)
xlist_11.extend(xlist_33)
xlist_11.extend(xlist_44)
xlist_11.extend(xlist_55)
xlist_11.extend(xlist_66)

ylist_11.extend(ylist_22)
ylist_11.extend(ylist_33)
ylist_11.extend(ylist_44)
ylist_11.extend(ylist_55)
ylist_11.extend(ylist_66)


# Gettting a points in a target plane (xp,yp) in mm
point= 60 # number of points b*b
x_numpy = np.linspace(-100,100,point)
y_numpy = np.linspace(-100,100,point)
xplist = []
yplist = []

for x in x_numpy:
  for y in y_numpy:
    xplist.append(x)
    yplist.append(y)

#####Calculating irradiance#######
intensity_point = []
m = -( np.log(2) / np.log(np.cos(psi))) 
Ir0 = 200 #(mW)   # intensity


inten_sum_point = [] #empty list for saving results
for xp,yp in zip(xplist,yplist):
  intensity_point = []
  for x,y in zip(xlist_11,ylist_11):    
    E_point = ((z_distance**(m+1))*Ir0) / (((xp-x)**2) + ((yp-y)**2) + (z_distance**2))**((m+3)/2)
    intensity_point.append(E_point) 
  inten_sum_point.append(sum(intensity_point))


#statistics
import statistics
minim = min(inten_sum_point)
maxx = max(inten_sum_point)
print(f"1.Max E : {maxx} (Watt per m2)")
print (f"2.Min E: {minim} (Watt per m2) ")
omjer = minim / maxx
print("3.E min/E max:", omjer)
E_avarage = (sum(inten_sum_point)) / (len(inten_sum_point))
print ("4.E_avarage:" , E_avarage)
u = minim / E_avarage            
print("5.Uniformity of E , u = Emin/Evarage, (the best is when u>0.8):", u)


import plotly.graph_objects as go
import plotly.offline as go_offline
#prepare data in 
nten_numpy = np.array(inten_sum_point)
Z =  nten_numpy.reshape(point,point) #reshaping list to array shape(b , b)
fig=go.Figure(data = go.Surface(z=Z, x = x_numpy, y = y_numpy,opacity=0.9, colorscale='Viridis'))
                      
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                             highlightcolor="limegreen", project_z=True))
fig.update_layout(title=(f" UV units , distance: {z_distance}(mm) and half angle:{psi_angle}deg"))  
fig.show()

fig = go.Figure( data = go.Scatter(x = xlist_11, y =ylist_11, opacity=0.9, mode='markers'))
fig.update_layout(title=("LEDs postions")) 
fig.show()
# Out:
# 1.Max E : 0.44277405136154824 (Watt per m2)
# 2.Min E: 0.2944791678242841 (Watt per m2)
# 3.E min/E max: 0.6650777454522204
# 4.E_avarage: 0.39079111915548215
# 5.Uniformity of E , u = Emin/Evarage, (the best is when u>0.8): 0.7535462127713326
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b9f829fd-07f8-4a48-96aa-050e244f6f30" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b9f829fd-07f8-4a48-96aa-050e244f6f30")) {
#                     Plotly.newPlot(
#                         'b9f829fd-07f8-4a48-96aa-050e244f6f30',
#                         [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]],